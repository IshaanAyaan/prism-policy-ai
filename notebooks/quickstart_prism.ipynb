# %% [markdown]
# # PRISM Quickstart
#
# This notebook is the fastest way to inspect the public PRISM artifacts.

# %%
from prism.data import headline_metrics, crash_model_comparison, primary_event_study, load_mechanism_comparison

metrics = headline_metrics()
metrics

# %%
crash_model_comparison()

# %%
primary_event_study()

# %%
load_mechanism_comparison().sort_values('macro_f1', ascending=False)
